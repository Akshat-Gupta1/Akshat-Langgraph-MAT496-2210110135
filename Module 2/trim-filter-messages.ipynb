# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/trim-filter-messages.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239435-lesson-4-trim-and-filter-messages)

# %% [markdown]
# # Filtering and trimming messages
#
# ## Review
#
# Now, we have a deeper understanding of a few things:
#
# * How to customize the graph state schema
# * How to define custom state reducers
# * How to use multiple graph state schemas
#
# ## Goals
#
# Now, we can start using these concepts with models in LangGraph!
#
# In the next few sessions, we'll build towards a chatbot that has long-term memory.
#
# Because our chatbot will use messages, let's first talk a bit more about advanced ways to work with messages in graph state.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langchain_core langgraph langchain_openai

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# We'll use [LangSmith](https://docs.smith.langchain.com/) for [tracing](https://docs.smith.langchain.com/concepts/tracing).
#
# We'll log to a project, `langchain-academy`.

# %% [markdown]
# ## Messages as state
#
# First, let's define some messages.

# %%
from pprint import pprint
from langchain_core.messages import AIMessage, HumanMessage
messages = [AIMessage(f"So you said you were researching ocean mammals?", name="Bot")]
messages.append(HumanMessage(f"Yes, I know about whales. But what others should I learn about?", name="Lance"))

for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?

# %% [markdown]
# Recall we can pass them to a chat model.

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")
llm.invoke(messages)
# Out:
# AIMessage(content='When it comes to ocean mammals, there\'s a fascinating variety beyond whales. Here are some you might want to explore:\n\n1. **Dolphins**: Highly intelligent and social creatures, dolphins belong to the family of cetaceans, just like whales. There are numerous species, including the well-known bottlenose dolphin.\n\n2. **Porpoises**: Similar to dolphins but generally smaller with different tooth shapes, porpoises include species like the harbor porpoise and vaquita, the latter of which is critically endangered.\n\n3. **Seals**: Falling under pinnipeds, seals are notable for their earless appearance and streamlined bodies. Examples include the harbor seal and the gray seal.\n\n4. **Sea Lions**: Unlike seals, sea lions have external ear flaps and larger flippers, allowing them to “walk” on land. California sea lions are particularly famous for their intelligence and frequent performances in aquariums.\n\n5. **Walruses**: Recognizable by their long tusks and whiskered faces, walruses are social animals with a distinct appearance compared to other pinnipeds.\n\n6. **Manatees and Dugongs**: Often referred to as "sea cows," these slow-moving herbivores are part of the Sirenia order and spend their days grazing on underwater vegetation.\n\n7. **Sea Otters**: Although not primarily ocean-dwelling, sea otters are important in marine ecosystems, especially kelp forests, where they play a role as a keystone species.\n\n8. **Polar Bears**: While they spend much of their time on sea ice rather than in the open ocean, polar bears depend heavily on marine environments for hunting seals.\n\nEach of these ocean mammals has unique adaptations and ecological roles within their respective environments. Learning about them offers insights into the diversity and complexity of marine ecosystems.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 374, 'prompt_tokens': 39, 'total_tokens': 413, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a788c5aef0', 'id': 'chatcmpl-CTscFyCD2rAUXLZW4SiKrJqtS4EDu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--68607cd8-433a-4ae8-96ab-8a8a85082704-0', usage_metadata={'input_tokens': 39, 'output_tokens': 374, 'total_tokens': 413, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# We can run our chat model in a simple graph with `MessagesState`.

# %%
from IPython.display import Image, display
from langgraph.graph import MessagesState
from langgraph.graph import StateGraph, START, END

# Node
def chat_model_node(state: MessagesState):
    return {"messages": llm.invoke(state["messages"])}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# Apart from whales, there are several other interesting ocean mammals you might want to learn about:
#
# 1. **Dolphins**: These are highly intelligent and social animals. There are many species, including the bottlenose dolphin and the killer whale (or orca, which is actually the largest member of the dolphin family).
#
# 2. **Porpoises**: Often confused with dolphins, porpoises are generally smaller and have different teeth and face shapes. They are less acrobatic than dolphins.
#
# 3. **Seals**: These include several species like the harbor seal, elephant seal, and grey seal. They are known for their playful nature and often haul out on rocks and beaches to rest.
#
# 4. **Sea Lions**: Similar to seals, but generally larger and with external ear flaps. They are known for their intelligence and ability to "walk" on land using their flippers.
#
# 5. **Walruses**: These are large marine mammals known for their long tusks, whiskers, and bulk. They are typically found in Arctic regions.
#
# 6. **Manatees**: Often called "sea cows," these gentle and slow-moving animals are usually found in shallow, warm coastal waters and waterways.
#
# 7. **Dugongs**: Closely related to manatees, dugongs are found in the Indian and Pacific Oceans and are known for grazing on seagrass.
#
# 8. **Otters**: Sea otters are known for their playful behavior and use of tools to open shellfish. They primarily inhabit the North Pacific Ocean.
#
# These mammals each have unique adaptations to live in marine environments, from sophisticated methods of communication to specialized feeding and diving behaviors. Studying them can provide insights into marine ecosystems and the challenges these animals face, such as climate change, pollution, and habitat loss.

# %% [markdown]
# ## Reducer
#
# A practical challenge when working with messages is managing long-running conversations.
#
# Long-running conversations result in high token usage and latency if we are not careful, because we pass a growing list of messages to the model.
#
# We have a few ways to address this.
#
# First, recall the trick we saw using `RemoveMessage` and the `add_messages` reducer.

# %%
from langchain_core.messages import RemoveMessage

# Nodes
def filter_messages(state: MessagesState):
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"messages": delete_messages}

def chat_model_node(state: MessagesState):    
    return {"messages": [llm.invoke(state["messages"])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("filter", filter_messages)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "filter")
builder.add_edge("filter", "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
# Message list with a preamble
messages = [AIMessage("Hi.", name="Bot", id="1")]
messages.append(HumanMessage("Hi.", name="Lance", id="2"))
messages.append(AIMessage("So you said you were researching ocean mammals?", name="Bot", id="3"))
messages.append(HumanMessage("Yes, I know about whales. But what others should I learn about?", name="Lance", id="4"))

# Invoke
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# In addition to whales, there are several other fascinating ocean mammals you might be interested in learning about:
#
# 1. **Dolphins**: Known for their intelligence and playful behavior, dolphins are highly social animals that live in pods. There are numerous species of dolphins, including the well-known bottlenose dolphin.
#
# 2. **Porpoises**: Similar to dolphins but generally smaller, porpoises are another group of toothed whales. They are shy and less acrobatic compared to dolphins.
#
# 3. **Seals**: These are semi-aquatic marine mammals that come in a variety of species, such as the harbor seal and the elephant seal. They spend a significant amount of time on land.
#
# 4. **Sea Lions**: Known for their external ear flaps and long front flippers, sea lions are more agile on land than seals. The California sea lion is a common species often seen in marine shows.
#
# 5. **Walruses**: These large, social animals are distinguished by their long tusks and whiskers. They primarily inhabit cold Arctic seas.
#
# 6. **Manatees and Dugongs**: Sometimes called sea cows, these gentle herbivores are known for their slow-moving, peaceful nature. Manatees are commonly found in warm coastal areas and rivers, while dugongs typically inhabit the Indian and Pacific oceans.
#
# 7. **Otters**: Sea otters are a keystone species known for their playful behavior and use of tools. They have a dense fur coat to keep warm in cold waters.
#
# 8. **Polar Bears**: While primarily terrestrial, polar bears are considered marine mammals due to their reliance on the ocean for food, particularly seals. They are strong swimmers and travel long distances in search of food.
#
# Each of these mammals plays a unique role in their ecosystems and have adaptations that suit their specific marine environments. They are all worth exploring further in your research on ocean mammals!

# %% [markdown]
# ## Filtering messages
#
# If you don't need or want to modify the graph state, you can just filter the messages you pass to the chat model.
#
# For example, just pass in a filtered list: `llm.invoke(messages[-1:])` to the model.

# %%
# Node
def chat_model_node(state: MessagesState):
    return {"messages": [llm.invoke(state["messages"][-1:])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# Let's take our existing list of messages, append the above LLM response, and append a follow-up question.

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me more about Narwhals!", name="Lance"))

# %%
for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# In addition to whales, there are several other fascinating ocean mammals you might be interested in learning about:
#
# 1. **Dolphins**: Known for their intelligence and playful behavior, dolphins are highly social animals that live in pods. There are numerous species of dolphins, including the well-known bottlenose dolphin.
#
# 2. **Porpoises**: Similar to dolphins but generally smaller, porpoises are another group of toothed whales. They are shy and less acrobatic compared to dolphins.
#
# 3. **Seals**: These are semi-aquatic marine mammals that come in a variety of species, such as the harbor seal and the elephant seal. They spend a significant amount of time on land.
#
# 4. **Sea Lions**: Known for their external ear flaps and long front flippers, sea lions are more agile on land than seals. The California sea lion is a common species often seen in marine shows.
#
# 5. **Walruses**: These large, social animals are distinguished by their long tusks and whiskers. They primarily inhabit cold Arctic seas.
#
# 6. **Manatees and Dugongs**: Sometimes called sea cows, these gentle herbivores are known for their slow-moving, peaceful nature. Manatees are commonly found in warm coastal areas and rivers, while dugongs typically inhabit the Indian and Pacific oceans.
#
# 7. **Otters**: Sea otters are a keystone species known for their playful behavior and use of tools. They have a dense fur coat to keep warm in cold waters.
#
# 8. **Polar Bears**: While primarily terrestrial, polar bears are considered marine mammals due to their reliance on the ocean for food, particularly seals. They are strong swimmers and travel long distances in search of food.
#
# Each of these mammals plays a unique role in their ecosystems and have adaptations that suit their specific marine environments. They are all worth exploring further in your research on ocean mammals!
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!

# %%
# Invoke, using message filtering
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# In addition to whales, there are several other fascinating ocean mammals you might be interested in learning about:
#
# 1. **Dolphins**: Known for their intelligence and playful behavior, dolphins are highly social animals that live in pods. There are numerous species of dolphins, including the well-known bottlenose dolphin.
#
# 2. **Porpoises**: Similar to dolphins but generally smaller, porpoises are another group of toothed whales. They are shy and less acrobatic compared to dolphins.
#
# 3. **Seals**: These are semi-aquatic marine mammals that come in a variety of species, such as the harbor seal and the elephant seal. They spend a significant amount of time on land.
#
# 4. **Sea Lions**: Known for their external ear flaps and long front flippers, sea lions are more agile on land than seals. The California sea lion is a common species often seen in marine shows.
#
# 5. **Walruses**: These large, social animals are distinguished by their long tusks and whiskers. They primarily inhabit cold Arctic seas.
#
# 6. **Manatees and Dugongs**: Sometimes called sea cows, these gentle herbivores are known for their slow-moving, peaceful nature. Manatees are commonly found in warm coastal areas and rivers, while dugongs typically inhabit the Indian and Pacific oceans.
#
# 7. **Otters**: Sea otters are a keystone species known for their playful behavior and use of tools. They have a dense fur coat to keep warm in cold waters.
#
# 8. **Polar Bears**: While primarily terrestrial, polar bears are considered marine mammals due to their reliance on the ocean for food, particularly seals. They are strong swimmers and travel long distances in search of food.
#
# Each of these mammals plays a unique role in their ecosystems and have adaptations that suit their specific marine environments. They are all worth exploring further in your research on ocean mammals!
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!
# ================================== Ai Message ==================================
#
# Narwhals are fascinating marine mammals known primarily for their long, spiral tusk, which resembles a unicorn's horn. They are a type of toothed whale and are closely related to belugas. Here are some interesting facts about narwhals:
#
# 1. **Habitat**: Narwhals are found in the Arctic waters around Greenland, Canada, and Russia. They prefer deep ocean waters and are particularly associated with the ice-covered seas of the High Arctic.
#
# 2. **Tusk**: The most distinctive feature of narwhals is the tusk, which is actually an elongated tooth. This tusk, usually found in males, can grow up to 10 feet long and is believed to have multiple functions, including sensory perception and mating displays. Some females also grow tusks, but it is less common.
#
# 3. **Diet**: Narwhals primarily feed on fish, shrimp, squid, and other marine animals. They are known to dive to great depths, often exceeding 1,500 meters (4,900 feet), to hunt for food.
#
# 4. **Social Behavior**: Narwhals are social animals and are often seen in groups, called pods, which typically consist of 5 to 20 individuals. These pods can sometimes gather to form larger groups of hundreds of narwhals during migration.
#
# 5. **Vocalizations**: Narwhals are known to be vocal and use a variety of clicks, whistles, and knocks to communicate with each other. These sounds are also used for echolocation, which helps them navigate and hunt in the dark, icy waters.
#
# 6. **Reproduction**: Female narwhals give birth to a single calf after a gestation period of about 14 months. Calves are typically born in spring or early summer and are dependent on their mothers for up to 20 months.
#
# 7. **Conservation Status**: Narwhals are considered near threatened due to factors like climate change, which affects their habitat, and human activities such as hunting and shipping. Their reliance on specific Arctic conditions makes them particularly vulnerable to environmental changes.
#
# 8. **Cultural Significance**: Narwhals have cultural and historical importance for Indigenous peoples of the Arctic. They have been hunted for their meat, blubber, and the prized tusk for centuries. The tusk has been traded and valued as a rare commodity throughout history.
#
# Overall, narwhals are remarkable creatures with unique adaptations that allow them to thrive in one of the planet's most extreme environments.

# %% [markdown]
# The state has all of the mesages.
#
# But, let's look at the LangSmith trace to see that the model invocation only uses the last message:
#
# https://smith.langchain.com/public/75aca3ce-ef19-4b92-94be-0178c7a660d9/r

# %% [markdown]
# ## Trim messages
#
# Another approach is to [trim messages](https://python.langchain.com/v0.2/docs/how_to/trim_messages/#getting-the-last-max_tokens-tokens), based upon a set number of tokens.
#
# This restricts the message history to a specified number of tokens.
#
# While filtering only returns a post-hoc subset of the messages between agents, trimming restricts the number of tokens that a chat model can use to respond.
#
# See the `trim_messages` below.

# %%
from langchain_core.messages import trim_messages

# Node
def chat_model_node(state: MessagesState):
    messages = trim_messages(
            state["messages"],
            max_tokens=100,
            strategy="last",
            token_counter=ChatOpenAI(model="gpt-4o"),
            allow_partial=False,
        )
    return {"messages": [llm.invoke(messages)]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me where Orcas live!", name="Lance"))

# %%
# Example of trimming messages
trim_messages(
            messages,
            max_tokens=100,
            strategy="last",
            token_counter=ChatOpenAI(model="gpt-4o"),
            allow_partial=False
        )
# Out:
# [HumanMessage(content='Tell me where Orcas live!', additional_kwargs={}, response_metadata={}, name='Lance')]

# %%
# Invoke, using message trimming in the chat_model_node 
messages_out_trim = graph.invoke({'messages': messages})

# %% [markdown]
# # Tracing in langsmith
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Let's look at the LangSmith trace to see the model invocation:
#
# https://smith.langchain.com/public/b153f7e9-f1a5-4d60-8074-f0d7ab5b42ef/r
